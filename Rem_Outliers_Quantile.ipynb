# %%
'''
for colab
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
'''
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import zipfile

# %%
CSV_PATH = 'data/heights.csv'

# %%
df = pd.read_csv(CSV_PATH)
df.head()
# Out:
#     name  height
# 0  mohan     5.9
# 1  maria     5.2
# 2  sakib     5.1
# 3    tao     5.5
# 4  virat     4.9

# %%
"""
  - setting a quantile threshold
  - 0.95, 0.05 is typical, but it could be different based on the problem and the data
"""
upper_threshold = df['height'].quantile(0.95)
lower_threshold = df['height'].quantile(0.05)

# %%
# now find all outliers in the set
df[df['height']>upper_threshold]
# Out:
#     name  height
# 9  imran    14.5

# %%
df[df['height']<lower_threshold]
# Out:
#       name  height
# 12  yoseph     1.2

# %%
"""
  Example of using domain knowledge would be know what is the possible height
  for people, using the tallest and smallest living people as the thresholds
"""

# %%
# remove the outliers
# had to use & not and
df[(df['height'] > lower_threshold) & (df['height'] < upper_threshold)]
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 13    binod     5.5

# %%
# Now it's time to move to a more complex data set
CSV_PATH = 'data/bhp.csv'
df = pd.read_csv(CSV_PATH)
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
# look at the size of  the data
df.shape
# Out:
# (13200, 7)

# %%
# describe is a great way to look at the quantiles and more
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
"""
  - Domain knowledge may not always come from yourself
  - You would could work in a team with someone with more knowledge that you and
    that would guide your choices
"""
lower_threshold, upper_threshold = df['price_per_sqft'].quantile([0.001, 0.999])
upper_threshold, lower_threshold
# Out:
# (50959.36200000098, 1366.184)

# %%
df[df['price_per_sqft'] > upper_threshold]
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5911         Mysore Road  1 Bedroom        45.0   1.0    23.0    1
# 6356        Bommenahalli  4 Bedroom      2940.0   3.0  2250.0    4
# 7012               other      1 BHK       650.0   1.0   500.0    1
# 7575               other      1 BHK       425.0   1.0   750.0    1
# 7799               other      4 BHK      2000.0   3.0  1063.0    4
# 8307   Bannerghatta Road      5 BHK      2500.0   4.0  1400.0    5
# 9436        Indira Nagar  4 Bedroom      2400.0   5.0  1250.0    4
# 11447         Whitefield  4 Bedroom        60.0   4.0   218.0    4
# 12328              other  4 Bedroom      4350.0   8.0  2600.0    4
#
#        price_per_sqft
# 345            672727
# 1005           200000
# 1106           625000
# 4044         12000000
# 4924          2300000
# 5911            51111
# 6356            76530
# 7012            76923
# 7575           176470
# 7799            53150
# 8307            56000
# 9436            52083
# 11447          363333
# 12328           59770

# %%
df[df['price_per_sqft'] < lower_threshold]
# Out:
#         location       size  total_sqft  bath  price  bhk  price_per_sqft
# 665    Yelahanka      3 BHK     35000.0   3.0  130.0    3             371
# 798        other  4 Bedroom     10961.0   4.0   80.0    4             729
# 1867       other  3 Bedroom     52272.0   2.0  140.0    3             267
# 2392       other  4 Bedroom      2000.0   3.0   25.0    4            1250
# 3934       other      1 BHK      1500.0   1.0   19.5    1            1300
# 5343       other      9 BHK     42000.0   8.0  175.0    9             416
# 5417      Ulsoor      4 BHK     36000.0   4.0  450.0    4            1250
# 5597    JP Nagar      2 BHK      1100.0   1.0   15.0    2            1363
# 7166   Yelahanka  1 Bedroom     26136.0   1.0  150.0    1             573
# 7862    JP Nagar      3 BHK     20000.0   3.0  175.0    3             875
# 8300     Kengeri      1 BHK      1200.0   1.0   14.0    1            1166
# 9144       other  4 Bedroom     10961.0   4.0   80.0    4             729
# 11635      Begur      3 BHK      2400.0   3.0   12.0    3             500
# 12355      other      4 BHK     16335.0   4.0  149.0    4             912

# %%
df_no_outliers = df[(df['price_per_sqft'] < upper_threshold) &
 (df['price_per_sqft'] > lower_threshold)]
df_no_outliers.shape
# Out:
# (13172, 7)

# %%
# Use sample to get random entries
df_no_outliers.sample(5)
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 11991               Thanisandra  4 Bedroom      3671.0   4.0  220.00    4
# 11518               Kammasandra      2 BHK       982.0   2.0   25.53    2
# 3608             Sarjapur  Road      2 BHK       984.0   2.0   45.91    2
# 2727                   KR Puram  4 Bedroom       600.0   5.0   75.00    4
# 11166  Electronic City Phase II      2 BHK       829.0   2.0   22.80    2
#
#        price_per_sqft
# 11991            5992
# 11518            2599
# 3608             4665
# 2727            12500
# 11166            2750

# %% [markdown]
# Airbnb Problem

# %%
ZIP_PATH = "data/airbnb.zip"
DESTINATION_DIR = "data/"

try:
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(DESTINATION_DIR)
    print(f"Success.")
except FileNotFoundError:
    print(f"'{ZIP_PATH}' not found.")
except zipfile.BadZipFile:
    print(f"'{ZIP_PATH}' is not a valid ZIP file.")
except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# Success.

# %%
CSV_PATH = "data/new_york_listings_2024.csv"
df = pd.read_csv(CSV_PATH)
df.head()
# Out:
#                    id                                               name  \
# 0             1312228         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382              Walter            Brooklyn        Clinton Hill
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 4   61391963      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  last_review  \
# 0  40.683710 -73.964610     Private room   55.0  ...   2015-12-20
# 1  40.766610 -73.988100  Entire home/apt  144.0  ...   2023-05-01
# 2  40.750764 -73.994605  Entire home/apt  187.0  ...   2023-12-18
# 3  40.835600 -73.942500     Private room  120.0  ...   2023-09-17
# 4  40.751120 -73.978600  Entire home/apt   85.0  ...   2023-12-03
#
#    reviews_per_month calculated_host_listings_count  availability_365  \
# 0               0.03                              1                 0
# 1               0.24                            139               364
# 2               1.67                              1               343
# 3               1.38                              2               363
# 4               0.24                            133               335
#
#    number_of_reviews_ltm     license  rating bedrooms beds          baths
# 0                      0  No License    5.0         1    1  Not specified
# 1                      2  No License   4.67         2    1              1
# 2                      6      Exempt   4.17         1    2              1
# 3                     12  No License   4.64         1    1              1
# 4                      3  No License   4.91    Studio    1              1
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (20758, 22)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.075800e+04  2.075800e+04  20758.000000  20758.000000   20758.000000
# mean   3.034044e+17  1.749316e+08     40.726798    -73.939161     187.776616
# std    3.901216e+17  1.725541e+08      0.060294      0.061403    1022.797208
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.708808e+07  2.041738e+07     40.684150    -73.980710      80.000000
# 50%    4.993003e+07  1.087271e+08     40.722820    -73.949587     125.000000
# 75%    7.216019e+17  3.144102e+08     40.763098    -73.917460     199.000000
# max    1.054376e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20758.000000       20758.000000       20758.000000
# mean        28.558435          42.642596           1.257910
# std         33.536518          73.561654           1.904661
# min          1.000000           1.000000           0.010000
# 25%         30.000000           4.000000           0.210000
# 50%         30.000000          14.000000           0.650000
# 75%         30.000000          49.000000           1.800000
# max       1250.000000        1865.000000          75.490000
#
#        calculated_host_listings_count  availability_365  \
# count                    20758.000000      20758.000000
# mean                        18.844108        205.990317
# std                         70.910834        135.087768
# min                          1.000000          0.000000
# 25%                          1.000000         87.000000
# 50%                          2.000000        215.000000
# 75%                          5.000000        353.000000
# max                        713.000000        365.000000
#
#        number_of_reviews_ltm          beds
# count           20758.000000  20758.000000
# mean               10.852105      1.723721
# std                21.357071      1.212272
# min                 0.000000      1.000000
# 25%                 1.000000      1.000000
# 50%                 3.000000      1.000000
# 75%                15.000000      2.000000
# max              1075.000000     42.000000

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
upper_threshold = df['price'].quantile(.99)
df_filtered = df[(df['price'] > 100) & (df['price'] < upper_threshold)]
df_filtered.head()
# Out:
#                    id                                               name  \
# 1            45277537  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971353993633883038  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 5            49584983  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 6            45457047  Rental unit in New York · ★4.33 · Studio · 1 b...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 5   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 6   51501835            Jeniffer           Manhattan      Hell's Kitchen
#
#     latitude  longitude        room_type  price  ...  last_review  \
# 1  40.766610 -73.988100  Entire home/apt  144.0  ...   2023-05-01
# 2  40.750764 -73.994605  Entire home/apt  187.0  ...   2023-12-18
# 3  40.835600 -73.942500     Private room  120.0  ...   2023-09-17
# 5  40.759950 -73.992960  Entire home/apt  115.0  ...   2023-07-29
# 6  40.767370 -73.987870  Entire home/apt  105.0  ...   2022-08-31
#
#    reviews_per_month calculated_host_listings_count  availability_365  \
# 1               0.24                            139               364
# 2               1.67                              1               343
# 3               1.38                              2               363
# 5               0.16                            139               276
# 6               0.10                            139               364
#
#    number_of_reviews_ltm     license  rating bedrooms beds baths
# 1                      2  No License   4.67         2    1     1
# 2                      6      Exempt   4.17         1    2     1
# 3                     12  No License   4.64         1    1     1
# 5                      2  No License    5.0         1    1     1
# 6                      0  No License   4.33    Studio    1     1
#
# [5 rows x 22 columns]

# %%
df_filtered.shape
# Out:
# (12548, 22)

# %%
df_filtered.sample(10)
# Out:
#                        id                                               name  \
# 3037   942635903441753168  Rental unit in New York · ★4.63 · 1 bedroom · ...
# 17244            41934934  Home in New York · ★5.0 · 1 bedroom · 1 bed · ...
# 5315             22345676  Rental unit in Brooklyn · ★4.59 · Studio · 1 b...
# 18569            35026161  Rental unit in New York · ★4.71 · Studio · 2 b...
# 14849  871933212421118004  Home in Queens · ★4.67 · 1 bedroom · 2 beds · ...
# 11570            23650568  Rental unit in Queens · ★4.89 · 2 bedrooms · 4...
# 17383            36943029  Rental unit in Queens · ★4.95 · 4 bedrooms · 7...
# 13172  607202437461817180  Rental unit in Brooklyn · ★4.76 · 1 bedroom · ...
# 9586             31311422  Rental unit in New York · ★4.88 · 1 bedroom · ...
# 2323              3530517  Loft in New York · ★4.95 · 2 bedrooms · 2 beds...
#
#          host_id               host_name neighbourhood_group  \
# 3037   401202937                   Eliza           Manhattan
# 17244   36793116  Mighty Tree Properties           Manhattan
# 5315     2921109                   Alice            Brooklyn
# 18569  113723310             MyNyHousing           Manhattan
# 14849   42814202                   Irina              Queens
# 11570   24771677                  Noelle              Queens
# 17383   75268330           Arel Concepts              Queens
# 13172  398614581                   Hamza            Brooklyn
# 9586   234357462                  Marina           Manhattan
# 2323    17773625                   Josée           Manhattan
#
#             neighbourhood   latitude  longitude        room_type  price  ...  \
# 3037              Midtown  40.746203 -73.988347     Private room  149.0  ...
# 17244             Midtown  40.764930 -73.978140  Entire home/apt  192.0  ...
# 5315   Bedford-Stuyvesant  40.689570 -73.929680  Entire home/apt  112.0  ...
# 18569     Upper West Side  40.789390 -73.972180  Entire home/apt  150.0  ...
# 14849       Fresh Meadows  40.743466 -73.788370     Private room  111.0  ...
# 11570             Bayside  40.763830 -73.771330  Entire home/apt  145.0  ...
# 17383             Astoria  40.764200 -73.906110  Entire home/apt  475.0  ...
# 13172         Fort Greene  40.687350 -73.975107     Private room  115.0  ...
# 9586         West Village  40.734120 -74.005060  Entire home/apt  196.0  ...
# 2323              Tribeca  40.719220 -74.002760  Entire home/apt  990.0  ...
#
#        last_review  reviews_per_month calculated_host_listings_count  \
# 3037    2023-12-21               1.79                             55
# 17244   2023-11-15               0.25                              6
# 5315    2020-07-17               0.65                              1
# 18569   2023-04-30               0.27                             60
# 14849   2023-10-11               1.08                              6
# 11570   2022-08-19               1.05                              3
# 17383   2023-11-12               3.60                              1
# 13172   2023-12-05               2.65                              4
# 9586    2023-11-19               0.80                              1
# 2323    2023-12-06               1.24                              1
#
#        availability_365  number_of_reviews_ltm     license  rating bedrooms  \
# 3037                128                      8      Exempt   4.63         1
# 17244               326                      3  No License    5.0         1
# 5315                 90                      0  No License   4.59    Studio
# 18569               335                      3  No License   4.71    Studio
# 14849               364                      9  No License   4.67         1
# 11570                92                      0  No License   4.89         2
# 17383                 0                     54  No License   4.95         4
# 13172               363                     26  No License   4.76         1
# 9586                333                      4  No License   4.88         1
# 2323                362                     18  No License   4.95         2
#
#       beds baths
# 3037     4     1
# 17244    1     1
# 5315     1     1
# 18569    2     1
# 14849    2     1
# 11570    4     1
# 17383    7     2
# 13172    1     1
# 9586     2     1
# 2323     2     2
#
# [10 rows x 22 columns]
